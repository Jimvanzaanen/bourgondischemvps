# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/dutch_municipalities.csv')
df1 = pd.read_csv('data/municipalities_holland.csv')

# %%
df.head()
# Out:
#     municipality       province    latitude  longitude  surface_km2  \
# 0    Aa en Hunze        Drenthe  53.010.485  6.749.528        278.9
# 1        Aalburg  Noord-Brabant  51.751.294  5.057.085         53.2
# 2       Aalsmeer  Noord-Holland  52.262.164  4.761.922         32.3
# 3         Aalten     Gelderland  51.926.667  6.580.678         97.0
# 4  Achtkarspelen      Friesland  53.210.357  6.153.565        104.0
#
#    surface_land_km2  surface_water_km2  population  avg_household_income_2012  \
# 0             276.4                2.5     25243.0                    35500.0
# 1              50.4                2.8     12859.0                    39100.0
# 2              20.4               11.9     30792.0                    40900.0
# 3              96.5                0.5     27030.0                    33300.0
# 4             102.4                1.6     28002.0                    30500.0
#
#    avg_woz_2014      ...       flag_color1  flag_color2  flag_color3  \
# 0      225000.0      ...             green       yellow          NaN
# 1      249000.0      ...             black          red       yellow
# 2      276000.0      ...               red        green        black
# 3      194000.0      ...             white        green          NaN
# 4      165000.0      ...             white          red        green
#
#    flag_color4  shield_symbol_1  shield_symbol_2  shield_symbol_3  \
# 0          NaN            crown            cross              NaN
# 1          NaN            wheel             lion              NaN
# 2          NaN             lion              eel              NaN
# 3          NaN             tree            sword              NaN
# 4         blue           church              NaN              NaN
#
#    shieldholder_1  shieldholder_2  shield_crown
# 0            deer            deer         crown
# 1             NaN             NaN         crown
# 2             NaN             NaN           NaN
# 3             NaN             NaN         crown
# 4             NaN             NaN         crown
#
# [5 rows x 40 columns]

# %%
df1.head()
# Out:
#     municipality       province    latitude  longitude  surface_km2  \
# 0    Aa en Hunze        Drenthe  53.010.485  6.749.528        278.9
# 1        Aalburg  Noord-Brabant  51.751.294  5.057.085         53.2
# 2       Aalsmeer  Noord-Holland  52.262.164  4.761.922         32.3
# 3         Aalten     Gelderland  51.926.667  6.580.678         97.0
# 4  Achtkarspelen      Friesland  53.210.357  6.153.565        104.0
#
#    surface_land_km2  surface_water_km2  population  avg_household_income_2012  \
# 0             276.4                2.5     25243.0                    35500.0
# 1              50.4                2.8     12859.0                    39100.0
# 2              20.4               11.9     30792.0                    40900.0
# 3              96.5                0.5     27030.0                    33300.0
# 4             102.4                1.6     28002.0                    30500.0
#
#    avg_woz_2014          ...           asylum_migrants_2006  \
# 0      225000.0          ...                           40.0
# 1      249000.0          ...                            5.0
# 2      276000.0          ...                           65.0
# 3      194000.0          ...                           55.0
# 4      165000.0          ...                           35.0
#
#    asylum_migrants_2007  asylum_migrants_2008  asylum_migrants_2009  \
# 0                  40.0                  40.0                  35.0
# 1                   5.0                   5.0                   5.0
# 2                  60.0                  60.0                  60.0
# 3                  55.0                  50.0                  50.0
# 4                  35.0                  30.0                  25.0
#
#    asylum_migrants_2010  asylum_migrants_2011  asylum_migrants_2012  \
# 0                  30.0                  30.0                  30.0
# 1                   5.0                   5.0                   5.0
# 2                  60.0                  55.0                  60.0
# 3                  55.0                  45.0                  35.0
# 4                  30.0                  25.0                  25.0
#
#    asylum_migrants_2013  asylum_migrants_2014  asylum_migrants_2015
# 0                  25.0                  25.0                  20.0
# 1                   5.0                   5.0                   5.0
# 2                  60.0                  60.0                  55.0
# 3                  35.0                  35.0                  35.0
# 4                  25.0                  25.0                  25.0
#
# [5 rows x 30 columns]

# %%
import shapefile
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-0f7eaf8a07a6> in <module>()
# ----> 1 import shapefile
#
# ModuleNotFoundError: No module named 'shapefile'
